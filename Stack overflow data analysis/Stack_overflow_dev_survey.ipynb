# %%
import pandas as pd

# %%
na_vals = ['NA','Missing']
df = pd.read_csv('C:\\Users\\saish\Desktop\\5th sem\\INT upgrad\\Data_sets\\stack-overflow-developer-survey-2022\\survey_results_public.csv',na_values=na_vals)
schema_df = pd.read_csv('C:\\Users\\saish\Desktop\\5th sem\\INT upgrad\\Data_sets\\stack-overflow-developer-survey-2022\\survey_results_schema.csv')

# %%
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# ...

# %%
schema_df.head()
# Out:
#       qid       qname                                           question  \
# 0   QID16          S0  <div><span style="font-size:19px;"><strong>Hel...
# 1   QID12    MetaInfo                                  Browser Meta Info
# 2    QID1          S1  <span style="font-size:22px; font-family: aria...
# 3    QID2  MainBranch  Which of the following options best describes ...
# 4  QID296  Employment  Which of the following best describes your cur...
#
#   force_resp  type selector
# 0      False    DB       TB
# 1      False  Meta  Browser
# 2      False    DB       TB
# 3       True    MC     SAVR
# 4      False    MC     MAVR

# %%
df.shape
# Out:
# (73268, 79)

# %%
pd.set_option('display.max_columns',79)
pd.set_option('display.max_rows',79)

# %%
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# ...

# %%
schema_df
# Out:
#        qid                 qname  \
# 0    QID16                    S0
# 1    QID12              MetaInfo
# 2     QID1                    S1
# 3     QID2            MainBranch
# 4   QID296            Employment
# 5   QID308            RemoteWork
# 6   QID297      CodingActivities
# 7   QID190                    S2
# 8    QID25               EdLevel
# 9   QID276             LearnCode
# 10  QID281       LearnCodeOnline
# 11  QID306  LearnCodeCoursesCert
# 12   QID32             YearsCode
# 13   QID34          YearsCodePro
# 14   QID31               DevType
# 15   QID29               OrgSize
# 16  QID278     PurchaseInfluence
# 17  QID279            BuyNewTool
# 18    QID6               Country
# 19   QID50              Currency
# 20   QID51             CompTotal
# 21   QID52              CompFreq
# 22   QID61                    S3
# 23  QID233              Language
# 24  QID262              Database
# 25  QID263              Platform
# 26  QID264              Webframe
# ...

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %%
df['TrueFalse_1']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 73263    Yes
# 73264     No
# 73265     No
# 73266    NaN
# 73267    NaN
# Name: TrueFalse_1, Length: 73268, dtype: object

# %%
df['TrueFalse_1'].value_counts()
# Out:
# Yes    23767
# No     12052
# Name: TrueFalse_1, dtype: int64

# %%
df.loc[0:2,'TrueFalse_1':'ConvertedCompYearly']
# Out:
#   TrueFalse_1 TrueFalse_2 TrueFalse_3           SurveyLength  \
# 0         NaN         NaN         NaN                    NaN
# 1         NaN         NaN         NaN               Too long
# 2         NaN         NaN         NaN  Appropriate in length
#
#                    SurveyEase  ConvertedCompYearly
# 0                         NaN                  NaN
# 1                   Difficult                  NaN
# 2  Neither easy nor difficult              40205.0

# %%
df.index
# Out:
# RangeIndex(start=0, stop=73268, step=1)

# %%
df.set_index('ResponseId',inplace = True)
schema_df.set_index('qname',inplace = True)

# %%
df.head()
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
#
#                      Employment                            RemoteWork  \
# ResponseId
# 1                           NaN                                   NaN
# 2           Employed, full-time                          Fully remote
# 3           Employed, full-time  Hybrid (some remote, some in-person)
# 4           Employed, full-time                          Fully remote
# 5           Employed, full-time  Hybrid (some remote, some in-person)
#
#                                     CodingActivities  \
# ResponseId
# 1                                                NaN
# ...

# %%
schema_df.head()
# Out:
#                qid                                           question  \
# qname
# S0           QID16  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo     QID12                                  Browser Meta Info
# S1            QID1  <span style="font-size:22px; font-family: aria...
# MainBranch    QID2  Which of the following options best describes ...
# Employment  QID296  Which of the following best describes your cur...
#
#            force_resp  type selector
# qname
# S0              False    DB       TB
# MetaInfo        False  Meta  Browser
# S1              False    DB       TB
# MainBranch       True    MC     SAVR
# Employment      False    MC     MAVR

# %%
schema_df.loc['Language','question']
# Out:
# 'Which <b>programming, scripting, and markup languages</b> have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the language and want to continue to do so, please check both boxes in that row.)'

# %%
schema_df.loc['CompFreq','question']
# Out:
# 'Is that compensation weekly, monthly, or yearly?'

# %%
schema_df.index
# Out:
# Index(['S0', 'MetaInfo', 'S1', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'S2', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'S3', 'Language', 'Database', 'Platform',
#        'Webframe', 'MiscTech', 'ToolsTech', 'NEWCollabTools', 'OpSys',
#        'VersionControlSystem', 'VCInteraction', 'VCHosting',
#        'OfficeStackAsync', 'OfficeStackSync', 'Blockchain', 'S4', 'NEWSOSites',
#        'SOVisitFreq', 'SOAccount', 'SOPartFreq', 'SOComm', 'S5', 'Age',
#        'Gender', 'Trans', 'Sexuality', 'Ethnicity', 'Accessibility',
#        'MentalHealth', 'S6', 'TBranch', 'ICorPM', 'WorkExp', 'Knowledge',
#        'Frequency', 'TimeSearching', 'TimeAnswering', 'Onboarding',
#        'ProfessionalTech', 'SOTeamsUsage', 'TrueFalse', 'S7', 'SurveyLength',
# ...

# %%
schema_df.sort_index(ascending = False)
# Out:
#                          qid  \
# qname
# YearsCodePro           QID34
# YearsCode              QID32
# WorkExp               QID288
# Webframe              QID264
# VersionControlSystem  QID283
# VCInteraction         QID284
# VCHosting             QID285
# TrueFalse_3           QID294
# TrueFalse_2           QID294
# TrueFalse_1           QID294
# TrueFalse             QID294
# Trans                 QID153
# ToolsTech             QID275
# TimeSearching         QID291
# TimeAnswering         QID292
# TBranch               QID299
# SurveyLength          QID132
# SurveyEase            QID133
# Sexuality             QID136
# SOVisitFreq           QID100
# SOTeamsUsage          QID286
# SOPartFreq            QID102
# SOComm                QID106
# SOAccount             QID101
# S7                    QID131
# S6                    QID295
# S5                    QID121
# S4                     QID91
# S3                     QID61
# S2                    QID190
# ...

# %%
schema_df.loc['CompTotal','question']
# Out:
# 'What is your current total compensation (salary, bonuses, and perks, before taxes and deductions)? Please enter a whole number in the box below, without any punctuation.  If you are paid hourly, please estimate an equivalent weekly, monthly, or yearly salary. If you prefer not to answer, please leave the box empty.'

# %%
countries = ['India','United States of America','Germany','Canada','Austria']
filt = (df['CompTotal'] > 70000) & (df['Country'].isin(countries))

# %%
# df[df['CompTotal'] > 70000]
df.loc[filt,['Country','LanguageHaveWorkedWith','CompTotal']]
# Out:
#                              Country  \
# ResponseId
# 12          United States of America
# 15          United States of America
# 18                           Austria
# 23                            Canada
# 26                           Germany
# ...                              ...
# 73227       United States of America
# 73230       United States of America
# 73255       United States of America
# 73259                          India
# 73265       United States of America
#
#                                        LanguageHaveWorkedWith  CompTotal
# ResponseId
# 12          C#;HTML/CSS;JavaScript;PowerShell;Python;Rust;SQL   194400.0
# 15                HTML/CSS;JavaScript;PHP;Python;R;Ruby;Scala   110000.0
# 18                                                 Python;SQL   190000.0
# 23                                          C#;SQL;TypeScript   125000.0
# 26                       Dart;Go;Java;Kotlin;Swift;TypeScript    85000.0
# ...

# %%
df['LanguageHaveWorkedWith']
# Out:
# ResponseId
# 1                                                      NaN
# 2                                    JavaScript;TypeScript
# 3                        C#;C++;HTML/CSS;JavaScript;Python
# 4                             C#;JavaScript;SQL;TypeScript
# 5              C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
#                                ...
# 73264    Bash/Shell;Dart;JavaScript;PHP;Python;SQL;Type...
# 73265            Bash/Shell;HTML/CSS;JavaScript;Python;SQL
# 73266                   HTML/CSS;JavaScript;PHP;Python;SQL
# 73267                                        C#;Delphi;VBA
# 73268          C#;JavaScript;Lua;PowerShell;SQL;TypeScript
# Name: LanguageHaveWorkedWith, Length: 73268, dtype: object

# %%
filt_py = df['LanguageHaveWorkedWith'].str.contains('Python', na = False)

# %%
df.loc[filt_py,['LanguageHaveWorkedWith']]
# Out:
#                                        LanguageHaveWorkedWith
# ResponseId
# 3                           C#;C++;HTML/CSS;JavaScript;Python
# 7               C++;HTML/CSS;JavaScript;PHP;Python;TypeScript
# 12          C#;HTML/CSS;JavaScript;PowerShell;Python;Rust;SQL
# 15                HTML/CSS;JavaScript;PHP;Python;R;Ruby;Scala
# 17                                       C#;Java;PHP;Python;R
# ...                                                       ...
# 73258                                            C;Python;SQL
# 73262       Bash/Shell;HTML/CSS;Java;JavaScript;Python;SQL...
# 73264       Bash/Shell;Dart;JavaScript;PHP;Python;SQL;Type...
# 73265               Bash/Shell;HTML/CSS;JavaScript;Python;SQL
# 73266                      HTML/CSS;JavaScript;PHP;Python;SQL
#
# [34155 rows x 1 columns]

# %%
df['LanguageHaveWorkedWith'].fillna(' ').apply(len) # apply on series
# Out:
# ResponseId
# 1         1
# 2        21
# 3        33
# 4        28
# 5        43
#          ..
# 73264    52
# 73265    41
# 73266    34
# 73267    13
# 73268    43
# Name: LanguageHaveWorkedWith, Length: 73268, dtype: int64

# %%
df.apply(len) # apply on dataframe
# Out:
# MainBranch                        73268
# Employment                        73268
# RemoteWork                        73268
# CodingActivities                  73268
# EdLevel                           73268
# LearnCode                         73268
# LearnCodeOnline                   73268
# LearnCodeCoursesCert              73268
# YearsCode                         73268
# YearsCodePro                      73268
# DevType                           73268
# OrgSize                           73268
# PurchaseInfluence                 73268
# BuyNewTool                        73268
# Country                           73268
# Currency                          73268
# CompTotal                         73268
# CompFreq                          73268
# LanguageHaveWorkedWith            73268
# LanguageWantToWorkWith            73268
# DatabaseHaveWorkedWith            73268
# DatabaseWantToWorkWith            73268
# PlatformHaveWorkedWith            73268
# ...

# %%
df.apply(len,axis='columns')
# Out:
# ResponseId
# 1        78
# 2        78
# 3        78
# 4        78
# 5        78
#          ..
# 73264    78
# 73265    78
# 73266    78
# 73267    78
# 73268    78
# Length: 73268, dtype: int64

# %%
len(df)
# Out:
# 73268

# %%
len(df['OrgSize'])
# Out:
# 73268

# %%
df['LanguageHaveWorkedWith'].fillna(' ').map(len)
# Out:
# ResponseId
# 1         1
# 2        21
# 3        33
# 4        28
# 5        43
#          ..
# 73264    52
# 73265    41
# 73266    34
# 73267    13
# 73268    43
# Name: LanguageHaveWorkedWith, Length: 73268, dtype: int64

# %%
df.rename(columns={'ConvertedCompYearly':'SalaryUSD'},inplace=True)

# %%
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 73264                          I am a developer by profession
# 73265                          I am a developer by profession
# 73266       I am not primarily a developer, but I write co...
# 73267                          I am a developer by profession
# 73268       I used to be a developer by profession, but no...
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# ...

# %%
df['TrueFalse_1']
# Out:
# ResponseId
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
#         ...
# 73264    Yes
# 73265     No
# 73266     No
# 73267    NaN
# 73268    NaN
# Name: TrueFalse_1, Length: 73268, dtype: object

# %%
df['TrueFalse_1'] = df['TrueFalse_1'].map({'Yes':True,'No':False})

# %%
df['TrueFalse_1']
# Out:
# ResponseId
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
#          ...
# 73264     True
# 73265    False
# 73266    False
# 73267      NaN
# 73268      NaN
# Name: TrueFalse_1, Length: 73268, dtype: object

# %%
df.sort_values(by=['Country','CompTotal'],ascending=[True,False],inplace=True)
df[['Country','CompTotal']].head(50)
# Out:
#                 Country   CompTotal
# ResponseId
# 6892        Afghanistan  55000000.0
# 38513       Afghanistan   1200000.0
# 43640       Afghanistan    700000.0
# 43691       Afghanistan    100000.0
# 2449        Afghanistan     40000.0
# 6243        Afghanistan     40000.0
# 23224       Afghanistan     40000.0
# 49274       Afghanistan      6000.0
# 55666       Afghanistan       200.0
# 3887        Afghanistan         1.0
# 5465        Afghanistan         1.0
# 6777        Afghanistan         1.0
# 17470       Afghanistan         1.0
# 2738        Afghanistan         0.0
# 67667       Afghanistan         0.0
# 1960        Afghanistan         NaN
# 3642        Afghanistan         NaN
# 3776        Afghanistan         NaN
# 4503        Afghanistan         NaN
# 7945        Afghanistan         NaN
# 8891        Afghanistan         NaN
# 10234       Afghanistan         NaN
# 10911       Afghanistan         NaN
# 13852       Afghanistan         NaN
# ...

# %%
df['SalaryUSD'].nlargest(10)
# Out:
# ResponseId
# 40305    50000000.0
# 202      44790396.0
# 62027    35000000.0
# 70523    32500000.0
# 61044    28853768.0
# 18923    22500000.0
# 62224    22500000.0
# 66496    18000000.0
# 1291     15000000.0
# 24164    15000000.0
# Name: SalaryUSD, dtype: float64

# %%
df.nsmallest(10,'SalaryUSD')
# Out:
#                                                    MainBranch  \
# ResponseId
# 19913       I am not primarily a developer, but I write co...
# 39916                          I am a developer by profession
# 65743                          I am a developer by profession
# 64367       I am not primarily a developer, but I write co...
# 52006                          I am a developer by profession
# 36436                          I am a developer by profession
# 6124                           I am a developer by profession
# 32333                          I am a developer by profession
# 2377                           I am a developer by profession
# 27981                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 19913                                     I prefer not to say
# 39916       Employed, full-time;Independent contractor, fr...
# 65743                                     Employed, full-time
# ...

# %%
df['CompTotal'].head(15)
# Out:
# ResponseId
# 6892     55000000.0
# 38513     1200000.0
# 43640      700000.0
# 43691      100000.0
# 2449        40000.0
# 6243        40000.0
# 23224       40000.0
# 49274        6000.0
# 55666         200.0
# 3887            1.0
# 5465            1.0
# 6777            1.0
# 17470           1.0
# 2738            0.0
# 67667           0.0
# Name: CompTotal, dtype: float64

# %%
df['CompTotal'].median()
# Out:
# 77500.0

# %%
df.describe()
# Out:
#           CompTotal  VCHostingPersonal use  VCHostingProfessional use  \
# count  3.842200e+04                    0.0                        0.0
# mean   2.342434e+52                    NaN                        NaN
# std    4.591478e+54                    NaN                        NaN
# min    0.000000e+00                    NaN                        NaN
# 25%    3.000000e+04                    NaN                        NaN
# 50%    7.750000e+04                    NaN                        NaN
# 75%    1.540000e+05                    NaN                        NaN
# max    9.000000e+56                    NaN                        NaN
#
#             WorkExp     SalaryUSD
# count  36769.000000  3.807100e+04
# mean      10.242378  1.707613e+05
# std        8.706850  7.814132e+05
# min        0.000000  1.000000e+00
# 25%        4.000000  3.583200e+04
# 50%        8.000000  6.784500e+04
# 75%       15.000000  1.200000e+05
# max       50.000000  5.000000e+07

# %%
df.median()
# Out:
# C:\Users\saish\AppData\Local\Temp/ipykernel_4100/530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# CompTotal                    77500.0
# VCHostingPersonal use            NaN
# VCHostingProfessional use        NaN
# WorkExp                          8.0
# TrueFalse_1                      1.0
# SalaryUSD                    67845.0
# dtype: float64

# %%
df['Country'].count()
# Out:
# 71771

# %%
df['Country'].value_counts()
# Out:
# United States of America                                13543
# India                                                    6639
# Germany                                                  5395
# United Kingdom of Great Britain and Northern Ireland     4190
# Canada                                                   2490
#                                                         ...
# Seychelles                                                  1
# Monaco                                                      1
# Solomon Islands                                             1
# Burkina Faso                                                1
# Djibouti                                                    1
# Name: Country, Length: 180, dtype: int64

# %%
country_grp = df.groupby(['Country'])
country_grp

# %%
country_grp['Country']

# %%
country_grp.get_group("India")
# Out:
#                                                    MainBranch  \
# ResponseId
# 64898                          I am a developer by profession
# 12132                          I am a developer by profession
# 25938                          I am a developer by profession
# 9796                           I am a developer by profession
# 57354                          I am a developer by profession
# ...                                                       ...
# 73134       I am not primarily a developer, but I write co...
# 73179                          I am a developer by profession
# 73194       I used to be a developer by profession, but no...
# 73256                          I am a developer by profession
# 73258                                   I am learning to code
#
#                      Employment                            RemoteWork  \
# ResponseId
# 64898       Employed, full-time                          Fully remote
# ...

# %%
filt = df['Country']=='India'
df.loc[filt]['CompTotal'].median()
# Out:
# 885000.0

# %%
country_grp['CompTotal'].median()
# Out:
# Country
# Afghanistan                                 6000.0
# Albania                                     5500.0
# Algeria                                    75000.0
# Andorra                                    31500.0
# Angola                                    600000.0
#                                            ...
# Venezuela, Bolivarian Republic of...        1094.0
# Viet Nam                                15000000.0
# Yemen                                      20750.0
# Zambia                                      6200.0
# Zimbabwe                                     950.0
# Name: CompTotal, Length: 180, dtype: float64

# %%
country_grp['CompTotal'].median().loc['India']
# Out:
# 885000.0

# %%
country_grp['CompTotal'].agg(['median','mean'])
# Out:
#                                           median          mean
# Country
# Afghanistan                               6000.0  3.808414e+06
# Albania                                   5500.0  5.104657e+05
# Algeria                                  75000.0  8.754444e+04
# Andorra                                  31500.0  7.677250e+04
# Angola                                  600000.0  1.287990e+09
# ...                                          ...           ...
# Venezuela, Bolivarian Republic of...      1094.0  4.498590e+03
# Viet Nam                              15000000.0  4.443807e+07
# Yemen                                    20750.0  1.071667e+05
# Zambia                                    6200.0  5.613333e+03
# Zimbabwe                                   950.0  9.445000e+04
#
# [180 rows x 2 columns]

# %%
filt = filt = df['Country']=='India'
df.loc[filt]['LanguageHaveWorkedWith'].str.contains('Python').sum()
# Out:
# 3081

# %%
country_grp['LanguageHaveWorkedWith'].str.contains('Python').sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4100/3764435434.py in <module>
# ----> 1 country_grp['LanguageHaveWorkedWith'].str.contains('Python').sum()
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     909             return self[attr]
#     910
# --> 911         raise AttributeError(
#     912             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     913         )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
country_grp['LanguageHaveWorkedWith'].apply(lambda x : x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              25
# Albania                                  19
# Algeria                                  19
# Andorra                                   4
# Angola                                    3
#                                        ...
# Venezuela, Bolivarian Republic of...     52
# Viet Nam                                136
# Yemen                                     4
# Zambia                                    6
# Zimbabwe                                 11
# Name: LanguageHaveWorkedWith, Length: 180, dtype: int64

# %%
country_respondants = df['Country'].value_counts()
country_respondants
# Out:
# United States of America                                13543
# India                                                    6639
# Germany                                                  5395
# United Kingdom of Great Britain and Northern Ireland     4190
# Canada                                                   2490
#                                                         ...
# Seychelles                                                  1
# Monaco                                                      1
# Solomon Islands                                             1
# Burkina Faso                                                1
# Djibouti                                                    1
# Name: Country, Length: 180, dtype: int64

# %%
py_series = country_grp['LanguageHaveWorkedWith'].apply(lambda x : x.str.contains('Python').sum())
py_series
# Out:
# Country
# Afghanistan                              25
# Albania                                  19
# Algeria                                  19
# Andorra                                   4
# Angola                                    3
#                                        ...
# Venezuela, Bolivarian Republic of...     52
# Viet Nam                                136
# Yemen                                     4
# Zambia                                    6
# Zimbabwe                                 11
# Name: LanguageHaveWorkedWith, Length: 180, dtype: int64

# %%
python_df = pd.concat([country_respondants,py_series],axis='columns',sort=False)
python_df
# Out:
#                                                     Country  \
# United States of America                              13543
# India                                                  6639
# Germany                                                5395
# United Kingdom of Great Britain and Northern Ir...     4190
# Canada                                                 2490
# ...                                                     ...
# Seychelles                                                1
# Monaco                                                    1
# Solomon Islands                                           1
# Burkina Faso                                              1
# Djibouti                                                  1
#
#                                                     LanguageHaveWorkedWith
# United States of America                                              7017
# India                                                                 3081
# ...

# %%
python_df.rename(columns={'Country':'NumOfResponses','LanguageHaveWorkedWith':'knownPython'},inplace=True)
python_df
# Out:
#                                                     NumOfResponses  \
# United States of America                                     13543
# India                                                         6639
# Germany                                                       5395
# United Kingdom of Great Britain and Northern Ir...            4190
# Canada                                                        2490
# ...                                                            ...
# Seychelles                                                       1
# Monaco                                                           1
# Solomon Islands                                                  1
# Burkina Faso                                                     1
# Djibouti                                                         1
#
#                                                     knownPython
# United States of America                                   7017
# ...

# %%
python_df['PctOfPython'] = (python_df['knownPython']/python_df['NumOfResponses'])*100
python_df
# Out:
#                                                     NumOfResponses  \
# United States of America                                     13543
# India                                                         6639
# Germany                                                       5395
# United Kingdom of Great Britain and Northern Ir...            4190
# Canada                                                        2490
# ...                                                            ...
# Seychelles                                                       1
# Monaco                                                           1
# Solomon Islands                                                  1
# Burkina Faso                                                     1
# Djibouti                                                         1
#
#                                                     knownPython  PctOfPython
# United States of America                                   7017    51.812745
# ...

# %%
python_df.sort_values(by='PctOfPython',ascending=False,inplace = True)
python_df.head(50)
# Out:
#                                   NumOfResponses  knownPython  PctOfPython
# Burkina Faso                                   1            1   100.000000
# Solomon Islands                                1            1   100.000000
# Saint Kitts and Nevis                          1            1   100.000000
# Brunei Darussalam                              1            1   100.000000
# Fiji                                           2            2   100.000000
# Papua New Guinea                               2            2   100.000000
# North Korea                                    4            4   100.000000
# Lao People's Democratic Republic               7            6    85.714286
# Timor-Leste                                    4            3    75.000000
# Suriname                                       4            3    75.000000
# Democratic Republic of the Congo               7            5    71.428571
# ...

# %%
df.isnull().sum()
# Out:
# MainBranch                            0
# Employment                         1559
# RemoteWork                        14310
# CodingActivities                  14369
# EdLevel                            1697
# LearnCode                          1688
# LearnCodeOnline                   22583
# LearnCodeCoursesCert              43879
# YearsCode                          1937
# YearsCodePro                      21435
# DevType                           11966
# OrgSize                           22229
# PurchaseInfluence                 22299
# BuyNewTool                         5305
# Country                            1497
# Currency                          22004
# CompTotal                         34846
# CompFreq                          28843
# LanguageHaveWorkedWith             2293
# LanguageWantToWorkWith             6241
# DatabaseHaveWorkedWith            13147
# DatabaseWantToWorkWith            22254
# PlatformHaveWorkedWith            23344
# ...

# %%
df['YearsCode'].head(10)
# Out:
# ResponseId
# 6892      3
# 38513    40
# 43640    12
# 43691     8
# 2449     15
# 6243      4
# 23224     9
# 49274    25
# 55666     8
# 3887     41
# Name: YearsCode, dtype: object

# %%
df['YearsCode'] = df['YearsCode'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4100/1298014615.py in <module>
# ----> 1 df['YearsCode'] = df['YearsCode'].astype(float)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ...

# %%
df['YearsCode'].unique()
# Out:
# array(['3', '40', '12', '8', '15', '4', '9', '25', '41',
#        'Less than 1 year', '18', '17', '2', '5', 'More than 50 years',
#        '7', '10', nan, '14', '1', '6', '50', '21', '28', '20', '49', '11',
#        '30', '13', '27', '22', '19', '16', '34', '37', '42', '33', '26',
#        '35', '38', '36', '31', '29', '24', '23', '32', '43', '39', '45',
#        '44', '47', '48', '46'], dtype=object)

# %%
df.YearsCode.value_counts()
# Out:
# 10                    5217
# 5                     5193
# 6                     4651
# 4                     4480
# 7                     4237
# 8                     4227
# 3                     4122
# 2                     3351
# 12                    2995
# 15                    2962
# 20                    2659
# 9                     2581
# 11                    1819
# 14                    1811
# 13                    1624
# 25                    1582
# 1                     1566
# Less than 1 year      1413
# 16                    1406
# 30                    1330
# 22                    1176
# 18                    1150
# 17                    1080
# 40                     777
# 24                     752
# 35                     742
# 23                     644
# 19                     563
# 26                     489
# 27                     485
# 21                     483
# 28                     425
# 32                     371
# 38                     288
# ...

# %%
df.YearsCode.replace('Less than 1 year',0,inplace=True)
df.YearsCode.replace('More than 50 years',51,inplace=True)

# %%
df['YearsCode'].unique()
# Out:
# array(['3', '40', '12', '8', '15', '4', '9', '25', '41', 0, '18', '17',
#        '2', '5', 51, '7', '10', nan, '14', '1', '6', '50', '21', '28',
#        '20', '49', '11', '30', '13', '27', '22', '19', '16', '34', '37',
#        '42', '33', '26', '35', '38', '36', '31', '29', '24', '23', '32',
#        '43', '39', '45', '44', '47', '48', '46'], dtype=object)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# 12.251307285752338

# %%
df.isnull().sum()
# Out:
# MainBranch                            0
# Employment                         1559
# RemoteWork                        14310
# CodingActivities                  14369
# EdLevel                            1697
# LearnCode                          1688
# LearnCodeOnline                   22583
# LearnCodeCoursesCert              43879
# YearsCode                          1937
# YearsCodePro                      21435
# DevType                           11966
# OrgSize                           22229
# PurchaseInfluence                 22299
# BuyNewTool                         5305
# Country                            1497
# Currency                          22004
# CompTotal                         34846
# CompFreq                          28843
# LanguageHaveWorkedWith             2293
# LanguageWantToWorkWith             6241
# DatabaseHaveWorkedWith            13147
# DatabaseWantToWorkWith            22254
# PlatformHaveWorkedWith            23344
# ...

# %%
df.dropna(axis='index',how='all',subset=['YearsCode'])
# Out:
#                                                    MainBranch  \
# ResponseId
# 6892                           I am a developer by profession
# 38513                          I am a developer by profession
# 43640                          I am a developer by profession
# 43691                          I am a developer by profession
# 2449                           I am a developer by profession
# ...                                                       ...
# 52824                                   I am learning to code
# 56764       I am not primarily a developer, but I write co...
# 57743                          I am a developer by profession
# 68960                          I am a developer by profession
# 71358                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 6892                                      Employed, full-time
# 38513                                     Employed, full-time
# ...

# %%
df.dropna(axis='index',how='all',subset=['YearsCode']).shape
# Out:
# (71331, 78)

# %%
df.shape
# Out:
# (73268, 78)

# %%
df['YearsCode'].isnull().sum()
# Out:
# 1937
